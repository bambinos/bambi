# %% [markdown]
# # Bayesian T-test

# %%
import arviz as az
import bambi as bmb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
az.style.use('arviz-darkgrid')

# %% [markdown]
# In this notebook we demo how to perform a Bayesian T-test

# %% [markdown]
# ## Generate data

# %%
np.random.seed(2935)
a = np.random.normal(5, 2, 1000)
b = np.random.normal(8, 2.5, 1000)
df = pd.DataFrame(
    {
        'Group': ['a'] * 1000 + ['b'] * 1000,
        'Val':np.hstack([a, b])
    }
)

# %%
az.plot_violin({'a':a, "b":b});

# %% [markdown]
# ### Analysis

# %%
model = bmb.Model(df)
results = model.fit('Val ~ Group')
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [Val_sigma, Group, Intercept]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:02<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 3 seconds.

# %%
# Here's the setup for the model
model.backend.model
# Out:
# $$
#             \begin{array}{rcl}
#             \text{Intercept} &\sim & \text{Normal}(\mathit{mu}=array,~\mathit{sigma}=array)\\\text{Group} &\sim & \text{Normal}(\mathit{mu}=array,~\mathit{sigma}=array)\\\text{Val_sigma} &\sim & \text{HalfStudentT}(\mathit{nu}=4.0,~\mathit{sigma}=2.7114284155028585)\\\text{Val} &\sim & \text{Normal}(\mathit{mu}=f(f(f(),~f(f(array,~\text{Intercept}))),~f(f(array,~\text{Group}))),~\mathit{sigma}=f(\text{Val_sigma}))
#             \end{array}
#             $$

# %%
# Model priors
model.plot();

# %%
az.plot_trace(results, kind='rank_vlines');

# %%
az.summary(results)
# Out:
#                mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_mean  \
# Intercept[0]  5.013  0.071   4.880    5.143      0.002    0.002    1014.0
# Group[0]      3.031  0.103   2.825    3.214      0.003    0.002    1033.0
# Val_sigma     2.250  0.036   2.183    2.318      0.001    0.001    1334.0
#
#               ess_sd  ess_bulk  ess_tail  r_hat
# Intercept[0]  1012.0    1017.0    1347.0    1.0
# Group[0]      1033.0    1035.0    1098.0    1.0
# Val_sigma     1333.0    1339.0    1258.0    1.0

# %%
# Grab just the posterior of the term of interest (group)
group_posterior = results.posterior['Group'].values
ax = az.plot_kde(group_posterior)
ax.axvline(0, 0, 3, linestyle='--', color='k');

# %%
# Probabiliy that posterior is > 0
(group_posterior > 0).mean()
# Out:
# 1.0
